# %%
import numpy as np
import pandas as pd 
import os
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
DATASET_PATH = "/home/ec2-user/fashion_data_extracted/fashion-dataset/images"
print(os.listdir(DATASET_PATH))
# Out:
# ['10000.jpg', '10001.jpg', '10002.jpg', '10003.jpg', '10004.jpg', '10005.jpg', '10006.jpg', '10007.jpg', '10008.jpg', '10009.jpg', '10010.jpg', '10011.jpg', '10012.jpg', '10013.jpg', '10014.jpg', '10015.jpg', '10016.jpg', '10017.jpg', '10018.jpg', '10019.jpg', '10020.jpg', '10021.jpg', '10022.jpg', '10023.jpg', '10024.jpg', '10025.jpg', '10026.jpg', '10027.jpg', '10028.jpg', '10029.jpg', '10030.jpg', '10031.jpg', '10032.jpg', '10033.jpg', '10034.jpg', '10035.jpg', '10037.jpg', '10039.jpg', '10040.jpg', '10041.jpg', '10042.jpg', '10043.jpg', '10044.jpg', '10045.jpg', '10046.jpg', '10047.jpg', '10048.jpg', '10049.jpg', '10050.jpg', '10051.jpg', '10052.jpg', '10053.jpg', '10054.jpg', '10056.jpg', '10057.jpg', '10058.jpg', '10059.jpg', '10060.jpg', '10061.jpg', '10062.jpg', '10063.jpg', '10064.jpg', '10065.jpg', '10066.jpg', '10067.jpg', '10068.jpg', '10069.jpg', '10070.jpg', '10071.jpg', '10072.jpg', '10073.jpg', '10074.jpg', '10075.jpg', '10076.jpg', '10078.jpg', '10079.jpg', '10080.jpg', '10081.jpg', '10082.jpg', '10083.jpg', '10088.jpg', '10089.jpg', '10092.jpg', '10093.jpg', '10095.jpg', '10096.jpg', '10097.jpg', '10098.jpg', '10099.jpg', '10101.jpg', '10102.jpg', '10104.jpg', '10105.jpg', '10106.jpg', '10107.jpg', '10108.jpg', '10109.jpg', '10110.jpg', '10111.jpg', '10112.jpg', '10113.jpg', '10114.jpg', '10115.jpg', '10117.jpg', '10122.jpg', '10125.jpg', '10126.jpg', '10127.jpg', '10128.jpg', '10129.jpg', '10130.jpg', '10131.jpg', '10133.jpg', '10134.jpg', '10135.jpg', '10136.jpg', '10137.jpg', '10138.jpg', '10139.jpg', '10140.jpg', '10141.jpg', '10142.jpg', '10143.jpg', '10144.jpg', '10145.jpg', '10146.jpg', '10147.jpg', '10148.jpg', '10149.jpg', '10150.jpg', '10151.jpg', '10152.jpg', '10153.jpg', '10154.jpg', '10155.jpg', '10156.jpg', '10157.jpg', '10158.jpg', '10159.jpg', '10160.jpg', '10161.jpg', '10162.jpg', '10164.jpg', '10166.jpg', '10167.jpg', '10168.jpg', '10169.jpg', '10170.jpg', '10171.jpg', '10172.jpg', '10173.jpg', '10174.jpg', '10175.jpg', '10176.jpg', '10177.jpg', '10178.jpg', '10179.jpg', '10180.jpg', '10181.jpg', '10182.jpg', '10183.jpg', '10184.jpg', '10185.jpg', '10186.jpg', '10187.jpg', '10188.jpg', '10189.jpg', '10190.jpg', '10192.jpg', '10193.jpg', '10194.jpg', '10195.jpg', '10196.jpg', '10197.jpg', '10198.jpg', '10199.jpg', '10200.jpg', '10202.jpg', '10203.jpg', '10204.jpg', '10205.jpg', '10207.jpg', '10208.jpg', '10209.jpg', '10210.jpg', '10211.jpg', '10213.jpg', '10214.jpg', '10215.jpg', '10216.jpg', '10217.jpg', '10219.jpg', '10220.jpg', '10221.jpg', '10222.jpg', '10223.jpg', '10224.jpg', '10225.jpg', '10226.jpg', '10227.jpg', '10228.jpg', '10229.jpg', '10230.jpg', '10231.jpg', '10235.jpg', '10236.jpg', '10237.jpg', '10238.jpg', '10239.jpg', '10240.jpg', '10241.jpg', '10242.jpg', '10243.jpg', '10244.jpg', '10245.jpg', '10246.jpg', '10247.jpg', '10248.jpg', '10249.jpg', '10250.jpg', '10252.jpg', '10253.jpg', '10254.jpg', '10255.jpg', '10256.jpg', '10257.jpg', '10258.jpg', '10259.jpg', '10260.jpg', '10261.jpg', '10262.jpg', '10263.jpg', '10264.jpg', '10265.jpg', '10266.jpg', '10267.jpg', '10268.jpg', '10269.jpg', '10270.jpg', '10271.jpg', '10272.jpg', '10273.jpg', '10274.jpg', '10275.jpg', '10276.jpg', '10277.jpg', '10278.jpg', '10279.jpg', '10280.jpg', '10281.jpg', '10282.jpg', '10283.jpg', '10284.jpg', '10285.jpg', '10286.jpg', '10287.jpg', '10288.jpg', '10289.jpg', '10290.jpg', '10292.jpg', '10293.jpg', '10294.jpg', '10295.jpg', '10296.jpg', '10297.jpg', '10298.jpg', '10299.jpg', '10300.jpg', '10301.jpg', '10302.jpg', '10303.jpg', '10304.jpg', '10305.jpg', '10306.jpg', '10307.jpg', '10308.jpg', '10309.jpg', '10312.jpg', '10313.jpg', '10314.jpg', '10315.jpg', '10316.jpg', '10317.jpg', '10318.jpg', '10319.jpg', '10320.jpg', '10321.jpg', '10322.jpg', '10323.jpg', '10324.jpg', '10325.jpg', '10326.jpg', '10327.jpg', '10328.jpg', '10329.jpg', '10330.jpg', '10331.jpg', '10332.jpg', '10333.jpg', '10334.jpg', '10335.jpg', '10336.jpg', '10338.jpg', '10339.jpg', '10340.jpg', '10341.jpg', '10342.jpg', '10343.j ...

# %%
imageIndex = os.listdir(DATASET_PATH)

head = 10


sampleImages = []


for i in range (head):
    sampleImages.append(imageIndex[i])
    print(sampleImages[i])


fig=plt.figure()
fig.set_figheight(15)
fig.set_figwidth(15)
axis=[]
row = len(sampleImages)/2
col = row+1

for i in range (len(sampleImages)):
    Image_path=DATASET_PATH+"/"+sampleImages[i]
    src = cv2.imread(Image_path)
    image = cv2.cvtColor(src, cv2.COLOR_BGR2RGB) 
    axis.append(fig.add_subplot(row, col, i+1))
    subplot_title=sampleImages[i]
    axis[-1].set_title(subplot_title)  
    plt.imshow(image)

fig.tight_layout()
plt.show()
# Out:
# 10000.jpg
# 10001.jpg
# 10002.jpg
# 10003.jpg
# 10004.jpg
# 10005.jpg
# 10006.jpg
# 10007.jpg
# 10008.jpg
# 10009.jpg
# <ipython-input-20-e7fad7ece5ac>:37: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   axis.append(fig.add_subplot(row, col, i+1))

# %%
df = pd.read_csv("/home/ec2-user/styles.csv", error_bad_lines=False)
df.head(10)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44446 entries, 0 to 44445
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   img_id              44446 non-null  int64
#  1   gender              44446 non-null  object
#  2   masterCategory      44446 non-null  object
#  3   subCategory         44446 non-null  object
#  4   articleType         44446 non-null  object
#  5   baseColour          44431 non-null  object
#  6   season              44425 non-null  object
#  7   year                44445 non-null  float64
#  8   usage               44129 non-null  object
#  9   productDisplayName  44440 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 3.4+ MB

# %%
df['image'] = df.apply(lambda row: str(row['img_id']) + ".jpg", axis=1)
df.head(10)
# Out:
#    img_id gender masterCategory subCategory  articleType baseColour  season  \
# 0   15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1   39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2   59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3   21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4   53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 5    1855    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 6   30805    Men        Apparel     Topwear       Shirts      Green  Summer
# 7   26960  Women        Apparel     Topwear       Shirts     Purple  Summer
# 8   29114    Men    Accessories       Socks        Socks  Navy Blue  Summer
# 9   30039    Men    Accessories     Watches      Watches      Black  Winter
#
#      year   usage                             productDisplayName      image
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt  15970.jpg
# 1  2012.0  Casual             Peter England Men Party Blue Jeans  39386.jpg
# 2  2016.0  Casual                       Titan Women Silver Watch  59263.jpg
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants  21379.jpg
# 4  2012.0  Casual                          Puma Men Grey T-shirt  53759.jpg
# 5  2011.0  Casual           Inkfruit Mens Chain Reaction T-shirt   1855.jpg
# 6  2012.0  Ethnic               Fabindia Men Striped Green Shirt  30805.jpg
# 7  2012.0  Casual                  Jealous 21 Women Purple Shirt  26960.jpg
# 8  2012.0  Casual                       Puma Men Pack of 3 Socks  29114.jpg
# 9  2016.0  Casual                         Skagen Men Black Watch  30039.jpg

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44446 entries, 0 to 44445
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   img_id              44446 non-null  int64
#  1   gender              44446 non-null  object
#  2   masterCategory      44446 non-null  object
#  3   subCategory         44446 non-null  object
#  4   articleType         44446 non-null  object
#  5   baseColour          44431 non-null  object
#  6   season              44425 non-null  object
#  7   year                44445 non-null  float64
#  8   usage               44129 non-null  object
#  9   productDisplayName  44440 non-null  object
#  10  image               44446 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 3.7+ MB

# %%
df.shape
# Out:
# (44446, 11)

# %%
augDf = pd.DataFrame({
    'filename': df['image'],
    'type': df['articleType']
})

# %%
# total number of entries in the dataframe
total_row = len(augDf)
print('total row count: ', total_row)
# Out:
# total row count:  44446

# %%
df.columns
# Out:
# Index(['id', 'gender', 'masterCategory', 'subCategory', 'articleType',
#        'baseColour', 'season', 'year', 'usage', 'productDisplayName', 'image'],
#       dtype='object')

# %%
unique_types = augDf['type'].unique().tolist()
total_class = len(unique_types)
print(total_class)
print(unique_types)
print(unique_types[0])
print(unique_types.index(unique_types[0]))
augDf['number_types'] = augDf['type'].apply(lambda x: unique_types.index(x) if x in unique_types else 0)
augDf.head(10)
# Out:
# 143
# ['Shirts', 'Jeans', 'Watches', 'Track Pants', 'Tshirts', 'Socks', 'Casual Shoes', 'Belts', 'Flip Flops', 'Handbags', 'Tops', 'Bra', 'Sandals', 'Shoe Accessories', 'Sweatshirts', 'Deodorant', 'Formal Shoes', 'Bracelet', 'Lipstick', 'Flats', 'Kurtas', 'Waistcoat', 'Sports Shoes', 'Shorts', 'Briefs', 'Sarees', 'Perfume and Body Mist', 'Heels', 'Sunglasses', 'Innerwear Vests', 'Pendant', 'Nail Polish', 'Laptop Bag', 'Scarves', 'Rain Jacket', 'Dresses', 'Night suits', 'Skirts', 'Wallets', 'Blazers', 'Ring', 'Kurta Sets', 'Clutches', 'Shrug', 'Backpacks', 'Caps', 'Trousers', 'Earrings', 'Camisoles', 'Boxers', 'Jewellery Set', 'Dupatta', 'Capris', 'Lip Gloss', 'Bath Robe', 'Mufflers', 'Tunics', 'Jackets', 'Trunk', 'Lounge Pants', 'Face Wash and Cleanser', 'Necklace and Chains', 'Duffel Bag', 'Sports Sandals', 'Foundation and Primer', 'Sweaters', 'Free Gifts', 'Trolley Bag', 'Tracksuits', 'Swimwear', 'Shoe Laces', 'Fragrance Gift Set', 'Bangle', 'Nightdress', 'Ties', 'Baby Dolls', 'Leggings', 'Highlighter and Blush', 'Travel Accessory', 'Kurtis', 'Mobile Pouch', 'Messenger Bag', 'Lip Care', 'Face Moisturisers', 'Compact', 'Eye Cream', 'Accessory Gift Set', 'Beauty Accessory', 'Jumpsuit', 'Kajal and Eyeliner', 'Water Bottle', 'Suspenders', 'Lip Liner', 'Robe', 'Salwar and Dupatta', 'Patiala', 'Stockings', 'Eyeshadow', 'Headband', 'Tights', 'Nail Essentials', 'Churidar', 'Lounge Tshirts', 'Face Scrub and Exfoliator', 'Lounge Shorts', 'Gloves', 'Mask and Peel', 'Wristbands', 'Tablet Sleeve', 'Ties and Cufflinks', 'Footballs', 'Stoles', 'Shapewear', 'Nehru Jackets', 'Salwar', 'Cufflinks', 'Jeggings', 'Hair Colour', 'Concealer', 'Rompers', 'Body Lotion', 'Sunscreen', 'Booties', 'Waist Pouch', 'Hair Accessory', 'Rucksacks', 'Basketballs', 'Lehenga Choli', 'Clothing Set', 'Mascara', 'Toner', 'Cushion Covers', 'Key chain', 'Makeup Remover', 'Lip Plumper', 'Umbrellas', 'Face Serum and Gel', 'Hat', 'Mens Grooming Kit', 'Rain Trousers', 'Body Wash and Scrub', 'Suits', 'Ipad']
# Shirts
# 0
#     filename         type  number_types
# 0  15970.jpg       Shirts             0
# 1  39386.jpg        Jeans             1
# 2  59263.jpg      Watches             2
# 3  21379.jpg  Track Pants             3
# 4  53759.jpg      Tshirts             4
# 5   1855.jpg      Tshirts             4
# 6  30805.jpg       Shirts             0
# 7  26960.jpg       Shirts             0
# 8  29114.jpg        Socks             5
# 9  30039.jpg      Watches             2

# %%
augDf['type'].value_counts()
# Out:
# Tshirts                7067
# Shirts                 3217
# Casual Shoes           2845
# Watches                2542
# Sports Shoes           2036
#                        ...
# Suits                     1
# Hair Accessory            1
# Cushion Covers            1
# Body Wash and Scrub       1
# Shoe Laces                1
# Name: type, Length: 143, dtype: int64

# %%
def getData(start,stop):
    x_data = []
    y_data = []
     
    
    for i in range(start, stop): 
        Image_path=DATASET_PATH+"/"+augDf.loc[i,'filename']
#         
        image = cv2.imread(Image_path,cv2.IMREAD_GRAYSCALE)
        try:
            resized_img = cv2.resize(image, dsize=(30, 40))
        except:
            print("Rejected Image: "+augDf.loc[i,'filename'])
            continue
        x_data.append(resized_img) 
        y_values = augDf.loc[i,'number_types'] 
        y_data.append(y_values)
                
    return x_data, y_data

# %%
X=[]
Y=[]

start = 0
stop = int(0.001*total_row) # testing with 0.1% image of the dataset
X,Y=getData(start,stop)

# %%
print(type(X))
print(X[0])
plt.title(unique_types[Y[0]])
plt.imshow(X[0])
# Out:
# <class 'list'>
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
X = np.array(X).reshape(-1, 30,40,1)
Y = np.array(Y)

# %%
X = X/255.0

# %%
Y = Y.reshape(len(X),)

# %%
print(type(X))
print(X.shape)
print(Y.shape)
print(X[0])
print(Y[0])
# Out:
# <class 'numpy.ndarray'>
# (44, 30, 40, 1)
# (44,)
# [[[1.        ]
#   [1.        ]
#   [1.        ]
#   ...
#   [1.        ]
#   [1.        ]
#   [1.        ]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   ...
#   [0.10980392]
#   [0.12156863]
#   [0.98823529]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   ...
#   [1.        ]
#   [1.        ]
#   [1.        ]]
#
#  ...
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   ...
#   [0.80784314]
#   [0.10980392]
#   [0.24705882]]
#
#  [[0.35294118]
#   [0.23137255]
#   [0.20784314]
#   ...
#   [0.20392157]
#   [0.30980392]
#   [0.30196078]]
#
#  [[0.17647059]
#   [1.        ]
#   [0.76078431]
#   ...
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# 0

# %%
X=[]
Y=[]
start = 0
stop = total_row
X,Y=getData(start,stop)

# conversion into numpy array
X = np.array(X).reshape(-1, 30,40,1)
Y = np.array(Y)

# normalizing
X = X/255

# processing Y_train for dimension matching
Y = Y.reshape(len(X),)
# Out:
# Rejected Image: 39403.jpg
# Rejected Image: 39410.jpg
# Rejected Image: 39401.jpg
# Rejected Image: 39425.jpg
# Rejected Image: 12347.jpg

# %%
print('Image Data Shape: ',X.shape)
print('Label Data Shape: ',Y.shape)
# Out:
# Image Data Shape:  (44419, 30, 40, 1)
# Label Data Shape:  (44419,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,` test_size = 0.1, random_state = 500)

# %%
print('Train Image Data Shape: ',X_train.shape)
print('Train Label Data Shape: ',Y_train.shape)
print('Test Image Data Shape: ',X_test.shape)
print('Test Label Data Shape: ',Y_test.shape)
# Out:
# Train Image Data Shape:  (39977, 30, 40, 1)
# Train Label Data Shape:  (39977,)
# Test Image Data Shape:  (4442, 30, 40, 1)
# Test Label Data Shape:  (4442,)

# %%
X_train, X_validate, Y_train, Y_validate = train_test_split(X_train, Y_train, test_size = 0.1, random_state = 500)

# %%
print('Train Image Data Shape: ',X_train.shape)
print('Train Label Data Shape: ',Y_train.shape)
print('Validation Image Data Shape: ',X_validate.shape)
print('Validation Label Data Shape: ',Y_validate.shape)
# Out:
# Train Image Data Shape:  (35979, 30, 40, 1)
# Train Label Data Shape:  (35979,)
# Validation Image Data Shape:  (3998, 30, 40, 1)
# Validation Label Data Shape:  (3998,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import os
import tensorflow as tf
import datetime, os
from tensorflow.keras.callbacks import TensorBoard
# Out:
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
def build_model():
    cnn_model = Sequential()
    cnn_model.add(Conv2D(32, (3, 3), input_shape = (30,40,3),activation='relu'))
    cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
    cnn_model.add(Dropout(0.25))

    cnn_model.add(Conv2D(64, (3, 3),activation='relu'))
    cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
    cnn_model.add(Dropout(0.25))

    cnn_model.add(Conv2D(128, (3, 3), activation='relu'))
    cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
    cnn_model.add(Dropout(0.25))

    cnn_model.add(Flatten())
    cnn_model.add(Dense(units = 512, activation = 'relu'))
    cnn_model.add(Dropout(0.25))
    cnn_model.add(Dense(units = total_class, activation = 'softmax'))
    return cnn_model

# %%
model=build_model()

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 38, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 19, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 19, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 12, 17, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 8, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 6, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 3, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 3, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 768)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               393728
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 143)               73359
# =================================================================
# Total params: 559,759
# Trainable params: 559,759
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def train_model(model):
    model.compile(loss ='sparse_categorical_crossentropy', optimizer='adam' ,metrics =['accuracy'])
    history = model.fit(X_train, Y_train, batch_size = 128, epochs = 150, verbose = 1, validation_data = (X_validate, Y_validate))

# %%
train_model(model)
# Out:
# Epoch 1/150
# 282/282 [==============================] - 10s 8ms/step - loss: 3.3985 - accuracy: 0.2023 - val_loss: 2.0439 - val_accuracy: 0.4572
# Epoch 2/150
# 282/282 [==============================] - 2s 7ms/step - loss: 1.9361 - accuracy: 0.4644 - val_loss: 1.3921 - val_accuracy: 0.5945
# Epoch 3/150
# 282/282 [==============================] - 2s 7ms/step - loss: 1.4491 - accuracy: 0.5814 - val_loss: 1.1432 - val_accuracy: 0.6518
# Epoch 4/150
# 282/282 [==============================] - 2s 7ms/step - loss: 1.2364 - accuracy: 0.6308 - val_loss: 1.0645 - val_accuracy: 0.6743
# Epoch 5/150
# 282/282 [==============================] - 2s 7ms/step - loss: 1.1306 - accuracy: 0.6536 - val_loss: 0.9778 - val_accuracy: 0.6986
# Epoch 6/150
# 282/282 [==============================] - 2s 7ms/step - loss: 1.0302 - accuracy: 0.6867 - val_loss: 0.8941 - val_accuracy: 0.7251
# Epoch 7/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.9860 - accuracy: 0.6903 - val_loss: 0.8885 - val_accuracy: 0.7324
# Epoch 8/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.9295 - accuracy: 0.7124 - val_loss: 0.8506 - val_accuracy: 0.7346
# Epoch 9/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.9044 - accuracy: 0.7117 - val_loss: 0.8321 - val_accuracy: 0.7404
# Epoch 10/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.8670 - accuracy: 0.7228 - val_loss: 0.8229 - val_accuracy: 0.7454
# Epoch 11/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.8289 - accuracy: 0.7308 - val_loss: 0.7915 - val_accuracy: 0.7599
# Epoch 12/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.7998 - accuracy: 0.7442 - val_loss: 0.7750 - val_accuracy: 0.7649
# Epoch 13/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.7692 - accuracy: 0.7479 - val_loss: 0.7715 - val_accuracy: 0.7651
# Epoch 14/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.7542 - accuracy: 0.7529 - val_loss: 0.7534 - val_accuracy: 0.7676
# Epoch 15/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.7253 - accuracy: 0.7617 - val_loss: 0.7586 - val_accuracy: 0.7634
# Epoch 16/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.7256 - accuracy: 0.7642 - val_loss: 0.7458 - val_accuracy: 0.7681
# Epoch 17/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.6996 - accuracy: 0.7707 - val_loss: 0.7300 - val_accuracy: 0.7786
# Epoch 18/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.6945 - accuracy: 0.7670 - val_loss: 0.7579 - val_accuracy: 0.7711
# Epoch 19/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.6815 - accuracy: 0.7713 - val_loss: 0.7272 - val_accuracy: 0.7761
# Epoch 20/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.6777 - accuracy: 0.7713 - val_loss: 0.7289 - val_accuracy: 0.7769
# Epoch 21/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.6661 - accuracy: 0.7776 - val_loss: 0.7452 - val_accuracy: 0.7751
# Epoch 22/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.6337 - accuracy: 0.7884 - val_loss: 0.7271 - val_accuracy: 0.7801
# Epoch 23/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.6197 - accuracy: 0.7883 - val_loss: 0.7145 - val_accuracy: 0.7816
# Epoch 24/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.6167 - accuracy: 0.7873 - val_loss: 0.7147 - val_accuracy: 0.7864
# Epoch 25/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.6171 - accuracy: 0.7877 - val_loss: 0.7214 - val_accuracy: 0.7824
# Epoch 26/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.5964 - accuracy: 0.7926 - val_loss: 0.7442 - val_accuracy: 0.7836
# Epoch 27/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.6060 - accuracy: 0.7885 - val_loss: 0.6994 - val_accuracy: 0.7926
# Epoch 28/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.5755 - accuracy: 0.8003 - val_loss: 0.7388 - val_accuracy: 0.7809
# Epoch 29/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.5815 - accuracy: 0.7996 - val_loss: 0.7037 - val_accuracy: 0.7939
# Epoch 30/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.5720 - accuracy: 0.8031 - val_loss: 0.6931 - val_accuracy: 0.7904
# Epoch 31/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.5568 - accuracy: 0.8071 - val_loss: 0.7091 - val_accuracy: 0.7909
# Epoch 32/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.5588 - accuracy: 0.8068 - val_loss: 0.7044 - val_accuracy: 0.7894
# Epoch 33/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.5481 - accuracy: 0.8102 - val_loss: 0.7271 - val_accuracy: 0.7884
# Epoch 34/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.5410 - accuracy: 0.8106 - val_loss: 0.7138 - val_accuracy: 0.7879
# Epoch 35/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.5433 - accuracy: 0.8100 - val_loss: 0.7106 - val_accuracy: 0.7934
# Epoch 36/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.5285 - accuracy: 0.8147 - val_loss: 0.7456 - val_accuracy: 0.7846
# Epoch 37/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.5237 - accuracy: 0.8156 - val_loss: 0.7048 - val_accuracy: 0.7986
# Epoch 38/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.5218 - accuracy: 0.8173 - val_loss: 0.7162 - val_accuracy: 0.7896
# Epoch 39/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.5202 - accuracy: 0.8189 - val_loss: 0.7521 - val_accuracy: 0.7859
# Epoch 40/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.5135 - accuracy: 0.8194 - val_loss: 0.7120 - val_accuracy: 0.7921
# Epoch 41/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.5212 - accuracy: 0.8165 - val_loss: 0.7176 - val_accuracy: 0.7881
# Epoch 42/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.5021 - accuracy: 0.8251 - val_loss: 0.7140 - val_accuracy: 0.7926
# Epoch 43/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4918 - accuracy: 0.8236 - val_loss: 0.7142 - val_accuracy: 0.7999
# Epoch 44/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4894 - accuracy: 0.8280 - val_loss: 0.7421 - val_accuracy: 0.7946
# Epoch 45/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4960 - accuracy: 0.8240 - val_loss: 0.7224 - val_accuracy: 0.7916
# Epoch 46/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4851 - accuracy: 0.8303 - val_loss: 0.7166 - val_accuracy: 0.8002
# Epoch 47/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.4774 - accuracy: 0.8306 - val_loss: 0.7257 - val_accuracy: 0.7929
# Epoch 48/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.4717 - accuracy: 0.8322 - val_loss: 0.7458 - val_accuracy: 0.7929
# Epoch 49/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4716 - accuracy: 0.8310 - val_loss: 0.7420 - val_accuracy: 0.7951
# Epoch 50/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4692 - accuracy: 0.8329 - val_loss: 0.7376 - val_accuracy: 0.7909
# Epoch 51/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4669 - accuracy: 0.8320 - val_loss: 0.7807 - val_accuracy: 0.7874
# Epoch 52/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4676 - accuracy: 0.8349 - val_loss: 0.7415 - val_accuracy: 0.7969
# Epoch 53/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.4615 - accuracy: 0.8343 - val_loss: 0.7321 - val_accuracy: 0.7989
# Epoch 54/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.4553 - accuracy: 0.8389 - val_loss: 0.7526 - val_accuracy: 0.7941
# Epoch 55/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4681 - accuracy: 0.8341 - val_loss: 0.7367 - val_accuracy: 0.7969
# Epoch 56/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4421 - accuracy: 0.8414 - val_loss: 0.7438 - val_accuracy: 0.7951
# Epoch 57/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4474 - accuracy: 0.8393 - val_loss: 0.7562 - val_accuracy: 0.7939
# Epoch 58/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4607 - accuracy: 0.8382 - val_loss: 0.7344 - val_accuracy: 0.7964
# Epoch 59/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.4321 - accuracy: 0.8446 - val_loss: 0.7676 - val_accuracy: 0.7921
# Epoch 60/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4277 - accuracy: 0.8461 - val_loss: 0.7376 - val_accuracy: 0.8009
# Epoch 61/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4443 - accuracy: 0.8430 - val_loss: 0.7470 - val_accuracy: 0.7941
# Epoch 62/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.4279 - accuracy: 0.8468 - val_loss: 0.7423 - val_accuracy: 0.8032
# Epoch 63/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.4367 - accuracy: 0.8441 - val_loss: 0.7366 - val_accuracy: 0.8044
# Epoch 64/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4211 - accuracy: 0.8508 - val_loss: 0.7469 - val_accuracy: 0.8034
# Epoch 65/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.4181 - accuracy: 0.8516 - val_loss: 0.7522 - val_accuracy: 0.7929
# Epoch 66/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4281 - accuracy: 0.8476 - val_loss: 0.7436 - val_accuracy: 0.7976
# Epoch 67/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4249 - accuracy: 0.8474 - val_loss: 0.7482 - val_accuracy: 0.7991
# Epoch 68/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4389 - accuracy: 0.8416 - val_loss: 0.7702 - val_accuracy: 0.7944
# Epoch 69/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4122 - accuracy: 0.8533 - val_loss: 0.7566 - val_accuracy: 0.8032
# Epoch 70/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4169 - accuracy: 0.8506 - val_loss: 0.7787 - val_accuracy: 0.7934
# Epoch 71/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3975 - accuracy: 0.8558 - val_loss: 0.7642 - val_accuracy: 0.7969
# Epoch 72/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4164 - accuracy: 0.8476 - val_loss: 0.7719 - val_accuracy: 0.7951
# Epoch 73/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3999 - accuracy: 0.8557 - val_loss: 0.7829 - val_accuracy: 0.7976
# Epoch 74/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4088 - accuracy: 0.8529 - val_loss: 0.7663 - val_accuracy: 0.8024
# Epoch 75/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3984 - accuracy: 0.8591 - val_loss: 0.7765 - val_accuracy: 0.7959
# Epoch 76/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4064 - accuracy: 0.8537 - val_loss: 0.7673 - val_accuracy: 0.8007
# Epoch 77/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3924 - accuracy: 0.8596 - val_loss: 0.7646 - val_accuracy: 0.7961
# Epoch 78/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3932 - accuracy: 0.8563 - val_loss: 0.7582 - val_accuracy: 0.7996
# Epoch 79/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.4045 - accuracy: 0.8515 - val_loss: 0.7672 - val_accuracy: 0.8054
# Epoch 80/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3963 - accuracy: 0.8559 - val_loss: 0.7890 - val_accuracy: 0.8024
# Epoch 81/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.3872 - accuracy: 0.8601 - val_loss: 0.7898 - val_accuracy: 0.8027
# Epoch 82/150
# 282/282 [==============================] - 2s 6ms/step - loss: 0.3816 - accuracy: 0.8616 - val_loss: 0.7773 - val_accuracy: 0.8004
# Epoch 83/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3776 - accuracy: 0.8647 - val_loss: 0.7885 - val_accuracy: 0.8002
# Epoch 84/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3939 - accuracy: 0.8567 - val_loss: 0.7680 - val_accuracy: 0.8054
# Epoch 85/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3985 - accuracy: 0.8569 - val_loss: 0.7693 - val_accuracy: 0.7966
# Epoch 86/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3757 - accuracy: 0.8624 - val_loss: 0.7941 - val_accuracy: 0.8002
# Epoch 87/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3763 - accuracy: 0.8625 - val_loss: 0.8143 - val_accuracy: 0.7966
# Epoch 88/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3919 - accuracy: 0.8594 - val_loss: 0.7579 - val_accuracy: 0.8082
# Epoch 89/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3694 - accuracy: 0.8671 - val_loss: 0.8059 - val_accuracy: 0.8002
# Epoch 90/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3814 - accuracy: 0.8641 - val_loss: 0.7871 - val_accuracy: 0.7976
# Epoch 91/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3661 - accuracy: 0.8686 - val_loss: 0.7828 - val_accuracy: 0.7991
# Epoch 92/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3692 - accuracy: 0.8636 - val_loss: 0.8086 - val_accuracy: 0.8027
# Epoch 93/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3642 - accuracy: 0.8678 - val_loss: 0.7753 - val_accuracy: 0.8047
# Epoch 94/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3738 - accuracy: 0.8670 - val_loss: 0.8098 - val_accuracy: 0.8097
# Epoch 95/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3768 - accuracy: 0.8644 - val_loss: 0.7876 - val_accuracy: 0.8014
# Epoch 96/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3828 - accuracy: 0.8636 - val_loss: 0.7864 - val_accuracy: 0.8087
# Epoch 97/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3815 - accuracy: 0.8624 - val_loss: 0.7967 - val_accuracy: 0.8067
# Epoch 98/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3645 - accuracy: 0.8699 - val_loss: 0.7899 - val_accuracy: 0.8004
# Epoch 99/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3701 - accuracy: 0.8661 - val_loss: 0.8265 - val_accuracy: 0.7951
# Epoch 100/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3697 - accuracy: 0.8687 - val_loss: 0.8617 - val_accuracy: 0.7956
# Epoch 101/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3663 - accuracy: 0.8670 - val_loss: 0.8159 - val_accuracy: 0.7999
# Epoch 102/150
# 282/282 [==============================] - 2s 8ms/step - loss: 0.3702 - accuracy: 0.8662 - val_loss: 0.7862 - val_accuracy: 0.8094
# Epoch 103/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3674 - accuracy: 0.8691 - val_loss: 0.7797 - val_accuracy: 0.8054
# Epoch 104/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3710 - accuracy: 0.8667 - val_loss: 0.8443 - val_accuracy: 0.7991
# Epoch 105/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3746 - accuracy: 0.8659 - val_loss: 0.7758 - val_accuracy: 0.8057
# Epoch 106/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3669 - accuracy: 0.8662 - val_loss: 0.7991 - val_accuracy: 0.8072
# Epoch 107/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3521 - accuracy: 0.8726 - val_loss: 0.8219 - val_accuracy: 0.8047
# Epoch 108/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3599 - accuracy: 0.8702 - val_loss: 0.7960 - val_accuracy: 0.8114
# Epoch 109/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3597 - accuracy: 0.8687 - val_loss: 0.8170 - val_accuracy: 0.8022
# Epoch 110/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3680 - accuracy: 0.8669 - val_loss: 0.8198 - val_accuracy: 0.8037
# Epoch 111/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3487 - accuracy: 0.8728 - val_loss: 0.8044 - val_accuracy: 0.8034
# Epoch 112/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3650 - accuracy: 0.8683 - val_loss: 0.8320 - val_accuracy: 0.8027
# Epoch 113/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3480 - accuracy: 0.8734 - val_loss: 0.8045 - val_accuracy: 0.8004
# Epoch 114/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3578 - accuracy: 0.8708 - val_loss: 0.7880 - val_accuracy: 0.8044
# Epoch 115/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3557 - accuracy: 0.8696 - val_loss: 0.8067 - val_accuracy: 0.8087
# Epoch 116/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3452 - accuracy: 0.8737 - val_loss: 0.7992 - val_accuracy: 0.8067
# Epoch 117/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3348 - accuracy: 0.8776 - val_loss: 0.7996 - val_accuracy: 0.8057
# Epoch 118/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3495 - accuracy: 0.8747 - val_loss: 0.8159 - val_accuracy: 0.8017
# Epoch 119/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3443 - accuracy: 0.8759 - val_loss: 0.8246 - val_accuracy: 0.8047
# Epoch 120/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3507 - accuracy: 0.8749 - val_loss: 0.8023 - val_accuracy: 0.8037
# Epoch 121/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3403 - accuracy: 0.8794 - val_loss: 0.8154 - val_accuracy: 0.8079
# Epoch 122/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3401 - accuracy: 0.8775 - val_loss: 0.8103 - val_accuracy: 0.8079
# Epoch 123/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3432 - accuracy: 0.8769 - val_loss: 0.7894 - val_accuracy: 0.8074
# Epoch 124/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3560 - accuracy: 0.8747 - val_loss: 0.8202 - val_accuracy: 0.8077
# Epoch 125/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3317 - accuracy: 0.8810 - val_loss: 0.8529 - val_accuracy: 0.8032
# Epoch 126/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3381 - accuracy: 0.8799 - val_loss: 0.8193 - val_accuracy: 0.8004
# Epoch 127/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3424 - accuracy: 0.8780 - val_loss: 0.8311 - val_accuracy: 0.7984
# Epoch 128/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3463 - accuracy: 0.8769 - val_loss: 0.8263 - val_accuracy: 0.8049
# Epoch 129/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3305 - accuracy: 0.8807 - val_loss: 0.8150 - val_accuracy: 0.8072
# Epoch 130/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3400 - accuracy: 0.8799 - val_loss: 0.8473 - val_accuracy: 0.8064
# Epoch 131/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3346 - accuracy: 0.8759 - val_loss: 0.8191 - val_accuracy: 0.8092
# Epoch 132/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3431 - accuracy: 0.8782 - val_loss: 0.8384 - val_accuracy: 0.8064
# Epoch 133/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3282 - accuracy: 0.8838 - val_loss: 0.8404 - val_accuracy: 0.8077
# Epoch 134/150
# 282/282 [==============================] - 2s 8ms/step - loss: 0.3337 - accuracy: 0.8823 - val_loss: 0.8323 - val_accuracy: 0.8112
# Epoch 135/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3365 - accuracy: 0.8793 - val_loss: 0.8231 - val_accuracy: 0.8054
# Epoch 136/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3236 - accuracy: 0.8856 - val_loss: 0.8357 - val_accuracy: 0.8084
# Epoch 137/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3343 - accuracy: 0.8812 - val_loss: 0.9027 - val_accuracy: 0.8014
# Epoch 138/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3391 - accuracy: 0.8809 - val_loss: 0.8451 - val_accuracy: 0.8067
# Epoch 139/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3338 - accuracy: 0.8824 - val_loss: 0.8489 - val_accuracy: 0.8037
# Epoch 140/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3224 - accuracy: 0.8850 - val_loss: 0.8819 - val_accuracy: 0.7969
# Epoch 141/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3347 - accuracy: 0.8777 - val_loss: 0.8636 - val_accuracy: 0.8004
# Epoch 142/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3263 - accuracy: 0.8861 - val_loss: 0.8201 - val_accuracy: 0.8092
# Epoch 143/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3268 - accuracy: 0.8801 - val_loss: 0.8334 - val_accuracy: 0.8069
# Epoch 144/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3314 - accuracy: 0.8837 - val_loss: 0.8493 - val_accuracy: 0.8069
# Epoch 145/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3166 - accuracy: 0.8858 - val_loss: 0.8531 - val_accuracy: 0.8007
# Epoch 146/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3280 - accuracy: 0.8803 - val_loss: 0.8593 - val_accuracy: 0.8089
# Epoch 147/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3239 - accuracy: 0.8838 - val_loss: 0.8392 - val_accuracy: 0.8029
# Epoch 148/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3198 - accuracy: 0.8867 - val_loss: 0.8591 - val_accuracy: 0.8012
# Epoch 149/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3295 - accuracy: 0.8826 - val_loss: 0.8592 - val_accuracy: 0.8007
# Epoch 150/150
# 282/282 [==============================] - 2s 7ms/step - loss: 0.3185 - accuracy: 0.8879 - val_loss: 0.8559 - val_accuracy: 0.8019

# %%
model.save('visual_product_recommend.h5')

# %%
from keras import models

# %%
model = models.load_model('visual_product_recommend.h5')

# %%
predicted_classes = model.predict_classes(X_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
#PC=PredictedClass #TC=TrueClass
L = 5
W = 5
fig, axes = plt.subplots(L, W, figsize = (12,12))
axes = axes.ravel()

for i in np.arange(0, L * W):  
    axes[i].imshow(X_test[i].reshape(40,30))
    axes[i].set_title(f"PC = {unique_types[predicted_classes[i]]}\n TC = {unique_types[Y_test[i]]}")
    axes[i].axis('off')
plt.subplots_adjust(wspace=0.5)
